# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---
#
# # Exercises
#
# For these exercises, you'll be creating a [Python class](https://www.hackerearth.com/practice/python/object-oriented-programming/classes-and-objects-i/tutorial/) in the *apputil.py* file.
#
# A few tips:
#
# - Some of these exercises will require some "JSON digging".
# - <font color='lightblue'>Your functions should still adhere to [best practices](https://codesignal.com/learn/courses/clean-code-basics-with-python/lessons/clean-function-design-in-python), so **your class should probably contain more functions than only the ones dictated below**.</font>

# %% [markdown]
# ## Exercise 1
#
# Create a Python class named `Genius` such that the following code initializes the object, and "saves" the access token as an attribute of the object. You'll need to use this attribute for Exercises 2 and 3.
#
# ```python
# from apputil import Genius
#
# genius = Genius(access_token="access_token")
# ```

# %%
from apputil import Genius

genius = Genius()

print(genius.access_token)
# Out:
# vw58dWIGES4DS1hb7pYPdbSyEIR_klztMKLcOgK3HtH2qFCn9EESV5p7xs96IiQc

# %% [markdown]
# ## Exercise 2
#
# Reference the `json_data` in the lab. Notice, when we search for an artist name (e.g., "Missy Elliot") in Genius, the result is a list of *songs* attributed to that artist. Suppose we want to capture information about the artist themselves.
#
# Create a method for our `Genius` class called `.get_artist(search_term)` which does the following:
#
# 1. Extract the (most likely, "Primary") Artist ID from the first "hit" of the `search_term`.
# 2. Use the [API path](https://docs.genius.com/#artists-h2) for this Artist ID to pull information about the artist.
# 3. **Return** the dictionary containing the resulting JSON object.
#
# For example, the following code should return a dictionary of artist information:
#
# ```python
# genius.get_artist("Radiohead")
# ```

# %%
from apputil import Genius
import json

genius = Genius()

artist = genius.get_artist("Radiohead")

print(artist)

with open('temp.json', 'w') as f:
    json.dump(artist, f)

print(type(artist))
# Out:
# {'meta': {'status': 200}, 'response': {'artist': {'alternate_names': [], 'api_path': '/artists/604', 'description': {'dom': {'tag': 'root', 'children': [{'tag': 'p', 'children': [{'tag': 'a', 'attributes': {'href': 'https://www.radiohead.com/', 'rel': 'noopener nofollow'}, 'children': ['Radiohead']}, ' emerged from the shadow of ‘90s Brit-pop with a sound that was moody, melodic, and explosive; with roots planted firmly in both alternative culture and the art-rock legacy of groups like ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Pink-floyd', 'rel': 'noopener'}, 'data': {'api_path': '/artists/694'}, 'children': ['Pink Floyd']}, ', ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Rem', 'rel': 'noopener'}, 'data': {'api_path': '/artists/8243'}, 'children': ['R.E.M.']}, ', ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/The-smiths', 'rel': 'noopener'}, 'data': {'api_path': '/artists/16669'}, 'children': ['The Smiths']}, ', and ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Talking-heads', 'rel': 'noopener'}, 'data': {'api_path': '/artists/13347'}, 'children': ['Talking Heads']}, '—from whose ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/Talking-heads-radio-head-lyrics', 'rel': 'noopener'}, 'data': {'api_path': '/songs/691833'}, 'children': ['song']}, ' they derived their name.']}, '', {'tag': 'p', 'children': ['They formed in 1985, as ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/On-a-friday', 'rel': 'noopener'}, 'data': {'api_path': '/artists/231288'}, 'children': ['On A Friday']}, ', named after the day they’d usually rehearse. The line-up hasn’t changed since: ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Thom-yorke', 'rel': 'noopener'}, 'data': {'api_path': '/artists/49096'}, 'children': ['Thom Yorke']}, ' (guitar/vocals), ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Ed-obrien', 'rel': 'noopener'}, 'data': {'api_path': '/artists/664806'}, 'children': ["Ed O'Brien"]}, ' (guitar), ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Philip-selway', 'rel': 'noopener'}, 'data': {'api_path': '/artists/240814'}, 'children': ['Philip Selway']}, ' (drums) and brothers ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Colin-greenwood', 'rel': 'noopener'}, 'data': {'api_path': '/artists/664805'}, 'children': ['Colin']}, ' and ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Jonny-greenwood', 'rel': 'noopener'}, 'data': {'api_path': '/artists/287476'}, 'children': ['Jonny Greenwood']}, ' on bass and lead guitar, respectively.']}, '', {'tag': 'p', 'children': ['In 1991, they signed with ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/artists/Emi-group-limited', 'rel': 'noopener'}, 'data': {'api_path': '/artists/1681459'}, 'children': ['EMI']}, ', changed their name to Radiohead, and recorded their first EP, ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/albums/Radiohead/Drill-ep', 'rel': 'noopener'}, 'data': {'api_path': '/albums/152652'}, 'children': [{'tag': 'em', 'children': ['Drill']}]}, '. They released the record in 1992 to little impact, debuting on the ', {'tag': 'a', 'attributes': {'href': 'https://www.theguardian.com/music/gallery/2007/oct/09/radiohead', 'rel': 'noopener nofollow'}, 'children': ['UK Charts at #101']}, '. It wasn’t until their catchy 1992 single ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/Radiohead-creep-lyrics', 'rel': 'noopener'}, 'data': {'api_path': '/songs/109096'}, 'children': ['“Creep”']}, ' became a massive hit that the band was launched into the limelight.']}, '', {'tag': 'p', 'children': ['When the band released ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/albums/Radiohead/Pablo-honey', 'rel': 'noopener'}, 'data': {'api_path': '/albums/21232'}, 'children': [{'tag': 'em', 'children': ['Pablo Honey']}]}, ' in 1993, however, most critics believed they w ...
# <class 'dict'>

# %% [markdown]
# ## Exercise 3
#
# Use the result from Exercise 2 to create another method for our `Genius` class called `.get_artists(search_terms)` (plural) which takes in a *list* of search terms, and returns a DataFrame containing a row for each search term, and the following columns:
#
# - `search_term`: the raw search term from `search_terms`
# - `artist_name`: the (most likely) artist name for the search term
# - `artist_id`: the Genius Artist ID for that artist, based on the API call
# - `followers_count`: the number of followers for that artist (if available)
#
# For example, the following should return a DataFrame with 4 rows:
#
# ```python
# genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# ```

# %%
from apputil import Genius

genius = Genius()

genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# Out:
#   search_term   artist_name  artist_id  followers
# 0     Rihanna       Rihanna         89       5883
# 1       Tycho         Tycho      53336         30
# 2        Seal  Lil Uzi Vert     217208       6332
# 3          U2            U2      23895        384

# %% [markdown]
# ## Bonus Exercise (optional)
#
# 1. Gather a list of 100+ various musical artists, and save this list in a TXT file.
# 2. Write a Python *script* that saves the result of `.get_artists` for these artists in a CSV file.
# 3. If you have time, adjust this script to use multiprocessing.
